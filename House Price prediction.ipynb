# %% [markdown]
# **Importing The Dependencies**

# %%
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn import metrics
from xgboost import XGBRegressor
import sklearn.datasets

# %%
# !unzip /content/archive.zip
# Out:
# unzip:  cannot find or open /content/archive.zip, /content/archive.zip.zip or /content/archive.zip.ZIP.

# %%
#import dataframe into csv file
house_price_dataset = pd.read_csv('/content/HousingData.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-47edd031e7fe> in <cell line: 2>()
#       1 #import dataframe into csv file
# ----> 2 house_price_dataset = pd.read_csv('/content/HousingData.csv')
#
# ...

# %%
# open dataset
house_price_dataset.head()

# %%
house_price_dataset.rename(columns = {'MEDV':'Price'}, inplace = True)

# %%
house_price_dataset.head()

# %%
#How many row and Columns in this dataset
house_price_dataset.shape

# %%
#check the value has missing value or not
house_price_dataset.isnull().sum()

# %%
house_price_dataset= house_price_dataset.dropna(how= 'any')

# %%
house_price_dataset.isnull().sum()

# %%
house_price_dataset.shape

# %%
#Statistical Method
house_price_dataset.describe()

# %%
##correlation
correlation = house_price_dataset.corr()

# %%
print(correlation)

# %%
plt.figure(figsize =(10,10))
sns.heatmap(correlation, cbar = True, square = True, fmt = '.1f', annot = True, annot_kws= {'size':8}, cmap = 'Greens')

# %%
#Separate the value
X = house_price_dataset.drop(['Price'],axis =1)
Y = house_price_dataset['Price']
print(X)
print(Y)

# %% [markdown]
# **Splitting **

# %%
X_train, Y_train , X_test, Y_test = train_test_split(X,Y, test_size = 0.2, random_state = 2)

# %%
print(X.shape, X_train.shape, X_test.shape)

# %% [markdown]
# **Load The Model**

# %%
Model = XGBRegressor()

# %%
Model.fit(X_train , Y_train)
